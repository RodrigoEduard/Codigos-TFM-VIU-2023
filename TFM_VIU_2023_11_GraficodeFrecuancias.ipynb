# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoEduard/Codigos-TFM-VIU-2023/blob/Tendencias_Frecuencistas_Anuales_en_comunas_por_zonas/TFM_VIU_2023_11_GraficodeFrecuancias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("dlyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘dlyr’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
library(dplyr)
library(magrittr)
library(readxl)
library(ggplot2)

# %%
conduccion <- read_excel("conduccion_110823_15_22.xlsx")

# %%
# ZONA 1 (NORTE): XV, I, II, III, IV: 24 comunas
#   DE ARICA Y PARINACOTA(1), DE TARAPACA(3), DE ANTOFAGASTA(6), DE ATACAMA(6), DE COQUIMBO(8)
norte_filtrado <- subset(conduccion, `NOMBRE REGION` %in% c("DE ARICA Y PARINACOTA", "DE ANTOFAGASTA", "DE TARAPACA", "DE ATACAMA", "DE COQUIMBO"))
comunas_filtrado <- norte_filtrado

table_year <- table(comunas_filtrado$`NOMBRE COMUNA`, comunas_filtrado$`AÑO INGRESO`)
table_year <- as.data.frame(table_year)
table_year$Var1 <- factor(table_year$Var1, levels = unique(comunas_filtrado$`NOMBRE COMUNA`))

table_year %>%
  ggplot(aes(x = Var2, y = Freq, group = Var1)) +
  geom_line(color = "#0b8185") +
  facet_wrap(vars(Var1), ncol = 4, scales = "free") +
  labs(x = NULL, y = NULL) +
  theme(
    legend.position = "none",
    plot.background = element_rect(fill = "white")
  )
# Out:
# plot without title

# %%
# ZONA 2: V, RM (CENTRO-METROPOLITANA): 24 comunas
#   DE VALPARAISO(16), METROPOLITANA DE SANTIAGO(8))
centro_metro_filtrado <- subset(conduccion, `NOMBRE REGION` %in% c("DE VALPARAISO", "METROPOLITANA DE SANTIAGO"))
comunas_filtrado <- centro_metro_filtrado

table_year <- table(comunas_filtrado$`NOMBRE COMUNA`, comunas_filtrado$`AÑO INGRESO`)
table_year <- as.data.frame(table_year)
table_year$Var1 <- factor(table_year$Var1, levels = unique(comunas_filtrado$`NOMBRE COMUNA`))

table_year %>%
  ggplot(aes(x = Var2, y = Freq, group = Var1)) +
  geom_line(color = "#0b8185") +
  facet_wrap(vars(Var1), ncol = 4, scales = "free") +
  labs(x = NULL, y = NULL) +
  theme(
    legend.position = "none",
    plot.background = element_rect(fill = "white")
  )
# Out:
# plot without title

# %%
# ZONA 3: VI, VII, VII, XVI, VIII (CENTRO SUR): 47 comunas
#   DEL LIBERTADOR B. O'HIGGINS(10), DEL MAULE(11), DE ÑUBLE(6), DEL BIOBIO(20)
centro_sur_filtrado <- subset(conduccion, `NOMBRE REGION` %in% c("DEL LIBERTADOR B. O'HIGGINS", "DEL MAULE", "DE ÑUBLE", "DEL BIOBIO"))
comunas_filtrado <- centro_sur_filtrado

table_year <- table(comunas_filtrado$`NOMBRE COMUNA`, comunas_filtrado$`AÑO INGRESO`)
table_year <- as.data.frame(table_year)
table_year$Var1 <- factor(table_year$Var1, levels = unique(comunas_filtrado$`NOMBRE COMUNA`))

table_year %>%
  ggplot(aes(x = Var2, y = Freq, group = Var1)) +
  geom_line(color = "#0b8185") +
  facet_wrap(vars(Var1), ncol = 4, scales = "free") +
  labs(x = NULL, y = NULL) +
  theme(
    legend.position = "none",
    plot.background = element_rect(fill = "white")
  )
# Out:
# plot without title

# %%
# ZONA 4: IX, XIV, X (SUR): 35 comunas
#   DE LA ARAUCANIA(15), DE LOS RIOS(7), DE LOS LAGOS(13)
sur_filtrado <- subset(conduccion, `NOMBRE REGION` %in% c("DE LA ARAUCANIA", "DE LOS RIOS", "DE LOS LAGOS"))
comunas_filtrado <- sur_filtrado

table_year <- table(comunas_filtrado$`NOMBRE COMUNA`, comunas_filtrado$`AÑO INGRESO`)
table_year <- as.data.frame(table_year)
table_year$Var1 <- factor(table_year$Var1, levels = unique(comunas_filtrado$`NOMBRE COMUNA`))

table_year %>%
  ggplot(aes(x = Var2, y = Freq, group = Var1)) +
  geom_line(color = "#0b8185") +
  facet_wrap(vars(Var1), ncol = 4, scales = "free") +
  labs(x = NULL, y = NULL) +
  theme(
    legend.position = "none",
    plot.background = element_rect(fill = "white")
  )
# Out:
# plot without title

# %%
# ZONA 5 (AUSTRAL): XI y XII: 9
#   DE AISEN DEL GRAL. C. IBAÑEZ DEL CAMPO(5), DE MAGALLANES Y DE LA ANTARTICA CHILENA(4)
austral_filtrado <- subset(conduccion, `NOMBRE REGION` %in% c("DE AISEN DEL GRAL. C. IBAÑEZ DEL CAMPO", "DE MAGALLANES Y DE LA ANTARTICA CHILENA"))
comunas_filtrado <- austral_filtrado

table_year <- table(comunas_filtrado$`NOMBRE COMUNA`, comunas_filtrado$`AÑO INGRESO`)
table_year <- as.data.frame(table_year)
table_year$Var1 <- factor(table_year$Var1, levels = unique(comunas_filtrado$`NOMBRE COMUNA`))

table_year %>%
  ggplot(aes(x = Var2, y = Freq, group = Var1)) +
  geom_line(color = "#0b8185") +
  facet_wrap(vars(Var1), ncol = 4, scales = "free") +
  labs(x = NULL, y = NULL) +
  theme(
    legend.position = "none",
    plot.background = element_rect(fill = "white")
  )
# Out:
# plot without title
