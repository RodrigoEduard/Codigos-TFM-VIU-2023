# %% [markdown]
# ---
# ## Script para el análisis de secuencias con TraMineR.
# >## Zona Centro Metropolitana
# ---
#
# **Autor**: Rodrigo Hernández A.
# **Tutora**: Dra. Nery Sofía Huerta.
# **Fecha**: 2 de Octubre, 2023.
#
# ---
#
# ### Descripción:
# >Script para el análisis de secuencias con TraMineR de la **zona Centro Metropolitana**, la cual consta de 2 regiones y 24 comunas con juzgados que registran el delito de conducción en estado de ebriedad.
#
# **Entorno**: R en Google Colab
# **Proyecto**: TFM - Máster en Big Data y Ciencia de Datos - Universidad Internacional de Valencia (VIU).
#
# ---

# %%
# ---- Instalación de paquetes necesarios ----
install.packages("readxl")
install.packages("TraMineR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘permute’, ‘vegan’

# %%
# ---- Importación de paquetes necesarios ----
library(readxl)
library(TraMineR)
library(cluster)
# Out:
# TraMineR stable version 2.2-8 (Built: 2023-10-05)
#
# Website: http://traminer.unige.ch
#
# Please type 'citation("TraMineR")' for citation information.

# %%
# ---- Carga de datos ---
#Descarga del conjunto de datos:
#    https://drive.google.com/drive/folders/1nyZ_bwVZIJUMBoozzjs8pi3jO1igzb7N
ZCM <- read_excel("/content/02-zonaCentroMetropolitana.xlsx")

# %%
ZCM <- as.data.frame(ZCM)
rownames(ZCM) <-  ZCM$Comuna
# ************************************************************************
seqstatl(ZCM[, 1:98])

ZCM.alphabet <- c("sobre","igual","bajo","sin_juzgado")
ZCM.labels <- c("Sobre","Igual","Bajo","Sin juzgado")
ZCM.scodes <- c("SO", "IG", "BA", "SJ")
ZCM.seq <- seqdef(ZCM, 2:98, alphabet = ZCM.alphabet, states = ZCM.scodes,
                  labels = ZCM.labels, xtstep = 4)
colores <- c( "#D98880","#2980B9","#73C6B6","#EB984E")  #Rojo, Azul, Verde, Naranja   https://htmlcolorcodes.com/
# Out:
#  [1] "bajo"          "CASABLANCA"    "COLINA"        "CURACAVI"
#  [5] "igual"         "ISLA PASCUA"   "LA CALERA"     "LA LIGUA"
#  [9] "LIMACHE"       "LOS ANDES"     "MELIPILLA"     "PETORCA"
# [13] "PUENTE ALTO"   "PUTAENDO"      "QUILLOTA"      "QUILPUE"
# [17] "QUINTERO"      "SAN ANTONIO"   "SAN BERNARDO"  "SAN FELIPE"
# [21] "SAN MIGUEL"    "SANTIAGO"      "sobre"         "TALAGANTE"
# [25] "VALPARAISO"    "VILLA ALEMANA" "VIÑA DEL MAR"
#  [>] state coding:
#
#        [alphabet]  [label]  [long label]
#
#      1  sobre       SO       Sobre
#
#      2  igual       IG       Igual
#
#      3  bajo        BA       Bajo
#
#      4  sin_juzgado SJ       Sin juzgado
#
#  [>] 24 sequences in the data set
#
#  [>] min/max sequence length: 97/97

# %%
#*************** Visualización de todas las secuencias **********
par(mar = c(5.0, 6.3, 4.0, 0.2)) #inferior, izquierdo, superior y derecho
options(repr.plot.width=13, repr.plot.height=7)
seqIplot(ZCM.seq, with.legend = FALSE, border = "grey", ytlab = "id", ylas = 1, ylab = "", cex.axis = 0.8 , xtlab = FALSE, cpal = colores, main = 'all sequences: 24 seq. (n=24)', xtstep = 2)
text(x = seq(1, length(colnames(ZCM.seq)), by = 2)-0.5, y = par("usr")[3] - 1.0, labels = colnames(ZCM.seq)[seq(1, length(colnames(ZCM.seq)), by = 2)], srt = 90, adj = c(1.0, 0.5), xpd = TRUE, cex = 1.0)
# Out:
# Plot with title “all sequences: 24 seq. (n=24)”

# %%
#*********Distribución de estados (Porcentaje de cada estado en el tiempo)
par(mar = c(5.2, 3.5, 3.0, 0.0)) #inferior, izquierdo, superior y derecho
options(repr.plot.width=13, repr.plot.height=7)
seqdplot(ZCM.seq, with.legend = FALSE, border = "grey", cpal = colores, main = "Rel. Freq.(n=24)", ylab= " ",xtlab = FALSE, cex.axis = 1.1);
grid(nx = 0, ny = 10, lty = 2, col = "black", lwd = 1)
axis(side = 1, at = seq(1, length(colnames(ZCM.seq)), by = 2)-.5, labels = colnames(ZCM.seq)[seq(1, length(colnames(ZCM.seq)), by = 2)], las = 2, cex.axis = 1.1)
# Out:
# Plot with title “Rel. Freq.(n=24)”

# %%
#*********Distribución Temporal de los Estados Modales.
par(mar = c(5.2, 3.5, 3.0, 0.0)) #inferior, izquierdo, superior y derecho
options(repr.plot.width=13, repr.plot.height=7)
seqmsplot(ZCM.seq, info = FALSE, with.legend = FALSE, border = "grey", cpal = colores, main = "State freq. (n=24)", ylab= " ", xtlab = FALSE, cex.axis = 1.2, ytstep = 2)
grid(nx = 0, ny = 12, lty = 2, col = "black", lwd = 1)
axis(side = 1, at = seq(1, length(colnames(ZCM.seq)), by = 2)-0.5, labels = colnames(ZCM.seq)[seq(1, length(colnames(ZCM.seq)), by = 2)], las = 2, cex.axis = 1.1, line = 0.6)
# Out:
# Warning message in plot.window(xlim, ylim, log = log, ...):
# “"ytstep" is not a graphical parameter”
# Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# “"ytstep" is not a graphical parameter”
# Plot with title “State freq. (n=24)”

# %%
#**********************Cálculo de distancias con Optimal Matching********
dist.om1 <- seqdist(ZCM.seq, method = "OM", indel = 1, sm = "TRATE")
cost_matrix <- seqsubm(ZCM.seq, method = "TRATE")
# Out:
#  [>] 24 sequences with 4 distinct states
#
#  [>] Computing sm with seqcost using  TRATE
#
#  [>] creating substitution-cost matrix using transition rates ...
#
#  [>] computing transition probabilities for states SO/IG/BA/SJ ...
#
#  [>] 24 distinct  sequences
#
#  [>] min/max sequence lengths: 97/97
#
#  [>] computing distances using the OM metric
#
#  [>] elapsed time: 0.133 secs
#
#  [>] creating substitution-cost matrix using transition rates ...
#
#  [>] computing transition probabilities for states SO/IG/BA/SJ ...

# %%
# Clustering y Visualización del Dendrograma con Método Ward
par(mar = c(0.0, 4.0, 4.0, 0.1)) #Bordes inferior, izquierdo, superior y derecho
options(repr.plot.width=13, repr.plot.height=7)
clusterward1 <- agnes(dist.om1, diss = TRUE, method = "ward")
plot(clusterward1, which.plot = 2)
rect.hclust(clusterward1,k=2,border="red")

cl1.4 <- cutree(clusterward1, k = 2)
cl1.4fac <- factor(cl1.4, labels = paste("Type", 1:2))
# Out:
# Plot with title “Dendrogram of  agnes(x = dist.om1, diss = TRUE, method = "ward")”

# %%
# Visualización de Secuencia para Tipo 1
par(mar = c(5.0, 2.5, 3.0, 0.0)) #Bordes inferior, izquierdo, superior y derecho
options(repr.plot.width=13, repr.plot.height=7)
seqdplot(ZCM.seq[cl1.4fac == "Type 1",], with.legend = FALSE, border = "grey", cpal = colores, main = "Type 1", ylab= " ",xtlab = FALSE, cex.axis = 1.1);
grid(nx = 0, ny = 10, lty = 2, col = "black", lwd = 1)
axis(side = 1, at = seq(1, length(colnames(ZCM.seq)), by = 2)-.5, labels = colnames(ZCM.seq)[seq(1, length(colnames(ZCM.seq)), by = 2)], las = 2, cex.axis = 1.1)
# Out:
# Plot with title “Type 1”

# %%
# Visualización de Secuencia para Tipo 2
par(mar = c(5.0, 2.5, 3.0, 0.0)) #Bordes inferior, izquierdo, superior y derecho
options(repr.plot.width=13, repr.plot.height=7)
seqdplot(ZCM.seq[cl1.4fac == "Type 2",], with.legend = FALSE, border = "grey", cpal = colores, main = "Type 2", ylab= " ",xtlab = FALSE, cex.axis = 1.1);
grid(nx = 0, ny = 10, lty = 2, col = "black", lwd = 1)
axis(side = 1, at = seq(1, length(colnames(ZCM.seq)), by = 2)-.5, labels = colnames(ZCM.seq)[seq(1, length(colnames(ZCM.seq)), by = 2)], las = 2, cex.axis = 1.1)
# Out:
# Plot with title “Type 2”
